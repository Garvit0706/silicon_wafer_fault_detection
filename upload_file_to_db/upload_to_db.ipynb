# %%
from pymongo.mongo_client import MongoClient
import pandas as pd
import json
import os

# %%
client = MongoClient("mongodb+srv://garvitgupta889:I0bvdn2v2EBwmLF5@garvit.hapddjc.mongodb.net/")
db = client.test

# %%
#Creating a database
db = client['Project']

#Creating a Collection
coll_create = db["wafer_fault"]

# %%
df=pd.read_csv(r'C:\Data Science\Wafer_Fault_Detection\notebook\wafer_23012020_041211.csv')
df.head(

)
df=df.drop("Unnamed: 0",axis=1)

# %%
json_record = list(json.loads(df.T.to_json()).values())

# %%
coll_create.insert_many(json_record)
# Out:
# InsertManyResult([ObjectId('66a5473a1f2faddd9f084db1'), ObjectId('66a5473a1f2faddd9f084db2'), ObjectId('66a5473a1f2faddd9f084db3'), ObjectId('66a5473a1f2faddd9f084db4'), ObjectId('66a5473a1f2faddd9f084db5'), ObjectId('66a5473a1f2faddd9f084db6'), ObjectId('66a5473a1f2faddd9f084db7'), ObjectId('66a5473a1f2faddd9f084db8'), ObjectId('66a5473a1f2faddd9f084db9'), ObjectId('66a5473a1f2faddd9f084dba'), ObjectId('66a5473a1f2faddd9f084dbb'), ObjectId('66a5473a1f2faddd9f084dbc'), ObjectId('66a5473a1f2faddd9f084dbd'), ObjectId('66a5473a1f2faddd9f084dbe'), ObjectId('66a5473a1f2faddd9f084dbf'), ObjectId('66a5473a1f2faddd9f084dc0'), ObjectId('66a5473a1f2faddd9f084dc1'), ObjectId('66a5473a1f2faddd9f084dc2'), ObjectId('66a5473a1f2faddd9f084dc3'), ObjectId('66a5473a1f2faddd9f084dc4'), ObjectId('66a5473a1f2faddd9f084dc5'), ObjectId('66a5473a1f2faddd9f084dc6'), ObjectId('66a5473a1f2faddd9f084dc7'), ObjectId('66a5473a1f2faddd9f084dc8'), ObjectId('66a5473a1f2faddd9f084dc9'), ObjectId('66a5473a1f2faddd9f08
# ...

# %%
mongo_client = MongoClient(os.getenv("mongodb+srv://garvitgupta889:<password>@garvit.hapddjc.mongodb.net/L"))

collection = mongo_client['Project']['wafer_fault']

# Fetch data from MongoDB collection
data = list(collection.find())
        
# Convert to DataFrame
df = pd.DataFrame(data)
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# Cell In[7], line 6
#       3 collection = mongo_client['Project']['wafer_fault']
#       5 # Fetch data from MongoDB collection
# ----> 6 data = list(collection.find())
#       8 # Convert to DataFrame
#       9 df = pd.DataFrame(data)
#
# File c:\Data Science\Wafer_Fault_Detection\env\Lib\site-packages\pymongo\cursor.py:1243, in Cursor.next(self)
#    1241 if self.__empty:
#    1242     raise StopIteration
# -> 1243 if len(self.__data) or self._refresh():
#    1244     return self.__data.popleft()
#    1245 else:
#
# File c:\Data Science\Wafer_Fault_Detection\env\Lib\site-packages\pymongo\cursor.py:1160, in Cursor._refresh(self)
#    1138         raise InvalidOperation(
#    1139             "Passing a 'hint' is required when using the min/max query"
#    1140             " option to ensure the query utilizes the correct index"
# ...

# %%
#mongo_client = MongoClient(os.getenv("MONGO_DB_URL"))
mongo_client.server_info()  # Attempt to retrieve server information
print("MongoDB connection successful!")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 2
#       1 #mongo_client = MongoClient(os.getenv("MONGO_DB_URL"))
# ----> 2 mongo_client.server_info()  # Attempt to retrieve server information
#       3 print("MongoDB connection successful!")
#
# File c:\Data Science\Wafer_Fault_Detection\env\Lib\site-packages\pymongo\mongo_client.py:1928, in MongoClient.server_info(self, session)
#    1917 def server_info(self, session: Optional[client_session.ClientSession] = None) -> dict[str, Any]:
#    1918     """Get information about the MongoDB server we're connected to.
#    1919
#    1920     :param session: a
#    (...)
#    1924        Added ``session`` parameter.
#    1925     """
#    1926     return cast(
#    1927         dict,
# -> 1928         self.admin.command(
#    1929             "buildinfo", read_preference=ReadPreference.PRIMARY, session=session
# ...

# %%
mongo_client.server_info()
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 mongo_client.server_info()
#
# File c:\Data Science\Wafer_Fault_Detection\env\Lib\site-packages\pymongo\mongo_client.py:1928, in MongoClient.server_info(self, session)
#    1917 def server_info(self, session: Optional[client_session.ClientSession] = None) -> dict[str, Any]:
#    1918     """Get information about the MongoDB server we're connected to.
#    1919
#    1920     :param session: a
#    (...)
#    1924        Added ``session`` parameter.
#    1925     """
#    1926     return cast(
#    1927         dict,
# -> 1928         self.admin.command(
#    1929             "buildinfo", read_preference=ReadPreference.PRIMARY, session=session
#    1930         ),
#    1931     )
#
# ...
